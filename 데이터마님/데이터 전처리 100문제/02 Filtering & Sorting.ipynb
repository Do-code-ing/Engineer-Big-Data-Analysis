# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv')

# %%
filt = df['quantity'] == 3
df[filt].head(5)
# Out:
#      order_id  quantity          item_name  \
# 409       178         3       Chicken Bowl
# 445       193         3               Bowl
# 689       284         3  Canned Soft Drink
# 818       338         3      Bottled Water
# 850       350         3  Canned Soft Drink
#
#                                     choice_description item_price
# 409  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 689                                        [Diet Coke]     $3.75
# 818                                                NaN     $3.27
# 850                                           [Sprite]     $3.75

# %%
df2 = df[filt].head(5)
df2.reset_index(drop=True)
# Out:
#    order_id  quantity          item_name  \
# 0       178         3       Chicken Bowl
# 1       193         3               Bowl
# 2       284         3  Canned Soft Drink
# 3       338         3      Bottled Water
# 4       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %%
df3 = df[['quantity', 'item_price']]
df3
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %%
df3['new_price'] = df3['item_price'].str[1:].astype('float')
df3
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21740\801321313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['new_price'] = df3['item_price'].str[1:].astype('float')
#       quantity item_price  new_price
# 0            1     $2.39        2.39
# 1            1     $3.39        3.39
# 2            1     $3.39        3.39
# 3            1     $2.39        2.39
# 4            2    $16.98       16.98
# ...        ...        ...        ...
# 4617         1    $11.75       11.75
# 4618         1    $11.75       11.75
# 4619         1    $11.25       11.25
# 4620         1     $8.75        8.75
# 4621         1     $8.75        8.75
#
# [4622 rows x 3 columns]

# %%
filt = df3['new_price'] <= 5
df3[filt].shape[0]
# Out:
# 1652

# %%
filt = df['item_name'] == 'Chicken Salad Bowl'
df[filt].reset_index(drop=True)
# Out:
#      order_id  quantity           item_name  \
# 0          20         1  Chicken Salad Bowl
# 1          60         2  Chicken Salad Bowl
# 2          94         2  Chicken Salad Bowl
# 3         111         1  Chicken Salad Bowl
# 4         137         2  Chicken Salad Bowl
# ..        ...       ...                 ...
# 105      1813         2  Chicken Salad Bowl
# 106      1822         1  Chicken Salad Bowl
# 107      1834         1  Chicken Salad Bowl
# 108      1834         1  Chicken Salad Bowl
# 109      1834         1  Chicken Salad Bowl
#
#                                     choice_description item_price
# 0    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# 1    [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 2    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50
# 3    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 4              [Fresh Tomato Salsa, Fajita Vegetables]    $17.50
# ...

# %%
df['new_price'] = df.loc[:,'item_price'].str[1:].astype('float')
filt = (df['new_price'] <= 9) & (df['item_name'] == 'Chicken Salad Bowl')
df[filt].head(5)
# Out:
#      order_id  quantity           item_name  \
# 44         20         1  Chicken Salad Bowl
# 256       111         1  Chicken Salad Bowl
# 526       220         1  Chicken Salad Bowl
# 528       221         1  Chicken Salad Bowl
# 529       221         1  Chicken Salad Bowl
#
#                                     choice_description item_price  new_price
# 44   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 256  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75        8.75
# 526  [Roasted Chili Corn Salsa, [Black Beans, Sour ...     $8.75        8.75
# 528  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $8.75        8.75
# 529  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $8.75        8.75

# %%
df.sort_values(by='new_price').reset_index(drop=True)
# Out:
#       order_id  quantity                     item_name  \
# 0          471         1                 Bottled Water
# 1          338         1                   Canned Soda
# 2         1575         1                   Canned Soda
# 3           47         1                   Canned Soda
# 4         1014         1                   Canned Soda
# ...        ...       ...                           ...
# 4617      1443         3                Veggie Burrito
# 4618      1443         4               Chicken Burrito
# 4619       511         4               Chicken Burrito
# 4620      1398         3                 Carnitas Bowl
# 4621      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $1.09        1.09
# 1                                           [Coca Cola]     $1.09        1.09
# ...

# %%
filt = df['item_name'].str.contains('Chips')
df[filt]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4596      1826         1                    Chips and Guacamole
# 4600      1827         1                    Chips and Guacamole
# 4605      1828         1                    Chips and Guacamole
# 4613      1831         1                                  Chips
# 4616      1832         1                    Chips and Guacamole
#
#      choice_description item_price  new_price
# 0                   NaN     $2.39        2.39
# 3                   NaN     $2.39        2.39
# 6                   NaN     $1.69        1.69
# ...

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                            Fizzy Lizzy
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                NoData     $2.39        2.39
# ...

# %%
df.iloc[:,1::2]
# Out:
#       quantity                                 choice_description  new_price
# 0            1                                             NoData       2.39
# 1            1                                       [Clementine]       3.39
# 2            1                                            [Apple]       3.39
# 3            1                                             NoData       2.39
# 4            2  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      16.98
# ...        ...                                                ...        ...
# 4617         1  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...      11.75
# 4618         1  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...      11.75
# 4619         1  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...      11.25
# 4620         1  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...       8.75
# 4621         1  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       8.75
#
# [4622 rows x 3 columns]

# %%
df.sort_values(by='new_price', ascending=False).reset_index(drop=True)
# Out:
#       order_id  quantity                     item_name  \
# 0         1443        15  Chips and Fresh Tomato Salsa
# 1         1398         3                 Carnitas Bowl
# 2          511         4               Chicken Burrito
# 3         1443         4               Chicken Burrito
# 4         1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 4617      1578         1                   Canned Soda
# 4618      1162         1                 Bottled Water
# 4619       567         1                   Canned Soda
# 4620      1014         1                   Canned Soda
# 4621       591         1                   Canned Soda
#
#                                      choice_description item_price  new_price
# 0                                                NoData    $44.25       44.25
# 1     [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25       35.25
# ...

# %%
filt = (df['item_name'] == 'Steak Salad') | (df['item_name'] == 'Bowl')
df[filt]
# Out:
#       order_id  quantity    item_name  \
# 445        193         3         Bowl
# 664        276         1  Steak Salad
# 673        279         1         Bowl
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price  new_price
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20       22.20
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99        8.99
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40        7.40
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99        8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     $8.99        8.99
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69        8.69

# %%
filt = (df['item_name'] == 'Steak Salad') | (df['item_name'] == 'Bowl')
df[filt].drop_duplicates('item_name')
# Out:
#      order_id  quantity    item_name  \
# 445       193         3         Bowl
# 664       276         1  Steak Salad
#
#                                     choice_description item_price  new_price
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20       22.20
# 664  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99        8.99

# %%
filt = (df['item_name'] == 'Steak Salad') | (df['item_name'] == 'Bowl')
df[filt].drop_duplicates('item_name', keep='last')
# Out:
#       order_id  quantity    item_name  \
# 673        279         1         Bowl
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price  new_price
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40        7.40
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69        8.69

# %%
filt = df['new_price'] >= df['new_price'].mean()
df[filt].head(5)
# Out:
#    order_id  quantity         item_name  \
# 4         2         2      Chicken Bowl
# 5         3         1      Chicken Bowl
# 7         4         1     Steak Burrito
# 8         4         1  Steak Soft Tacos
# 9         5         1     Steak Burrito
#
#                                   choice_description item_price  new_price
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98       10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25        9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25

# %%
filt = df['item_name'] == 'Izze'
df.loc[filt, 'item_name'] = 'Fizzy Lizzy'
df.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                   Fizzy Lizzy       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price  new_price
# 0     $2.39        2.39
# 1     $3.39        3.39
# 2     $3.39        3.39

# %%
df['choice_description'].isnull().sum()
# Out:
# 1246

# %%
filt = df['choice_description'].isnull()
df.loc[filt, 'choice_description'] = 'NoData'
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                            Fizzy Lizzy
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  new_price
# 0                                             NoData     $2.39        2.39
# 1                                       [Clementine]     $3.39        3.39
# 2                                            [Apple]     $3.39        3.39
# 3                                             NoData     $2.39        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98

# %%
filt = df['choice_description'].str.contains('Black')
df[filt].head(5)
# Out:
#     order_id  quantity             item_name  \
# 4          2         2          Chicken Bowl
# 7          4         1         Steak Burrito
# 9          5         1         Steak Burrito
# 11         6         1  Chicken Crispy Tacos
# 12         6         1    Chicken Soft Tacos
#
#                                    choice_description item_price  new_price
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75        8.75
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75        8.75

# %%
filt = ~df['choice_description'].str.contains('Vegetables')
len(df[filt])
# Out:
# 3900

# %%
filt = df['item_name'].str.startswith('N')
df[filt].head(3)
# Out:
#      order_id  quantity         item_name         choice_description  \
# 2           1         1  Nantucket Nectar                    [Apple]
# 22         11         1  Nantucket Nectar       [Pomegranate Cherry]
# 105        46         1  Nantucket Nectar  [Pineapple Orange Banana]
#
#     item_price  new_price
# 2       $3.39        3.39
# 22      $3.39        3.39
# 105     $3.39        3.39

# %%
filt = df['item_name'].str.len() >= 15
df[filt].head(3)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price  new_price
# 0             NoData     $2.39        2.39
# 2            [Apple]     $3.39        3.39
# 3             NoData     $2.39        2.39

# %%
lst = [1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98]
filt = df['new_price'].isin(lst)
len(df[filt])
# Out:
# 1393
